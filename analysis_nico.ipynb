# %%
import matplotlib.pyplot as plt
import pandas as pd
from utils import *
from matplotlib.colors import ListedColormap
from matplotlib.ticker import FuncFormatter


# %matplotlib inline

#increase plot size
plt.rcParams['figure.figsize'] = [20, 10]

import numpy as np
# maximum print option
np.set_printoptions(linewidth=400)

from model import Schelling

# %%
model = Schelling(width = 50, height = 50, density = 0.75, minority_pc = 0.3, homophily = 3,  policy = 'minimum_improvement', follow_policy=1.0, altruism = 0.2)
# Out:
# /Users/nicolalorusso/miniconda3/lib/python3.10/site-packages/mesa/agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 0 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (0, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (0, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (0, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (0, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (0, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (0, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (0, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (0, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (0, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (0, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (0, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (0, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (0, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (0, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (0, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (0, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (0, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (0, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (0, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (0, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (0, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (0, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (0, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (1, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (1, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (1, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (1, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (1, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (1, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (1, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (1, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (1, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (1, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (1, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (1, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (1, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (1, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (1, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (1, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (1, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (1, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (1, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (1, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (1, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (1, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (2, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (2, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (2, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (2, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (2, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (2, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (2, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (2, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (2, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (2, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (2, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (2, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (2, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (2, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (2, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (2, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (2, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (2, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (2, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (3, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (3, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (3, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (3, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (3, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (3, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (3, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (3, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 128 is being placed with
# place_agent() despite already having the position (3, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 129 is being placed with
# place_agent() despite already having the position (3, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 130 is being placed with
# place_agent() despite already having the position (3, 21). In most
# ...
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1828 is being placed with
# place_agent() despite already having the position (48, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1829 is being placed with
# place_agent() despite already having the position (48, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1830 is being placed with
# place_agent() despite already having the position (48, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1831 is being placed with
# place_agent() despite already having the position (48, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1832 is being placed with
# place_agent() despite already having the position (48, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1833 is being placed with
# place_agent() despite already having the position (48, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1834 is being placed with
# place_agent() despite already having the position (48, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1835 is being placed with
# place_agent() despite already having the position (48, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1836 is being placed with
# place_agent() despite already having the position (49, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1837 is being placed with
# place_agent() despite already having the position (49, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1838 is being placed with
# place_agent() despite already having the position (49, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1839 is being placed with
# place_agent() despite already having the position (49, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1840 is being placed with
# place_agent() despite already having the position (49, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1841 is being placed with
# place_agent() despite already having the position (49, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1842 is being placed with
# place_agent() despite already having the position (49, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1843 is being placed with
# place_agent() despite already having the position (49, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1844 is being placed with
# place_agent() despite already having the position (49, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1845 is being placed with
# place_agent() despite already having the position (49, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1846 is being placed with
# place_agent() despite already having the position (49, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1847 is being placed with
# place_agent() despite already having the position (49, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1848 is being placed with
# place_agent() despite already having the position (49, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1849 is being placed with
# place_agent() despite already having the position (49, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1850 is being placed with
# place_agent() despite already having the position (49, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1851 is being placed with
# place_agent() despite already having the position (49, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1852 is being placed with
# place_agent() despite already having the position (49, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1853 is being placed with
# place_agent() despite already having the position (49, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1854 is being placed with
# place_agent() despite already having the position (49, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1855 is being placed with
# place_agent() despite already having the position (49, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1856 is being placed with
# place_agent() despite already having the position (49, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1857 is being placed with
# place_agent() despite already having the position (49, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1858 is being placed with
# place_agent() despite already having the position (49, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1859 is being placed with
# place_agent() despite already having the position (49, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1860 is being placed with
# place_agent() despite already having the position (49, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1861 is being placed with
# place_agent() despite already having the position (49, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1862 is being placed with
# place_agent() despite already having the position (49, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1863 is being placed with
# place_agent() despite already having the position (49, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1864 is being placed with
# place_agent() despite already having the position (49, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1865 is being placed with
# place_agent() despite already having the position (49, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1866 is being placed with
# place_agent() despite already having the position (49, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1867 is being placed with
# place_agent() despite already having the position (49, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1868 is being placed with
# place_agent() despite already having the position (49, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1869 is being placed with
# place_agent() despite already having the position (49, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /Users/nicolalorusso/Library/Mobile Documents/com~apple~CloudDocs/ETH/ETH 9/Agent Based Modelling/css/model.py:123: UserWarning: Agent 1870 is being placed with
# place_agent() despite already having the position (49, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))

# %%
while model.running and model.schedule.steps < 100:
    model.step()
print(model.schedule.steps)  # Show how many steps have actually run
# Out:
# 60

# %%
model_out = model.datacollector.get_model_vars_dataframe()

# %%
model_out
# Out:
#     perc_happy  segregation
# 0     0.725815     0.528193
# 1     0.923036     0.555719
# 2     0.960983     0.564404
# 3     0.974345     0.568279
# 4     0.976483     0.572154
# 5     0.980224     0.574559
# 6     0.983431     0.577365
# 7     0.986104     0.578033
# 8     0.987173     0.579637
# 9     0.987707     0.580037
# 10    0.988242     0.580037
# 11    0.988242     0.583779
# 12    0.990379     0.582710
# 13    0.990914     0.583244
# 14    0.990914     0.583779
# 15    0.991448     0.583511
# 16    0.991448     0.584180
# 17    0.991448     0.585115
# 18    0.992517     0.585783
# 19    0.993052     0.586050
# 20    0.993052     0.586317
# 21    0.993052     0.586451
# 22    0.993586     0.587654
# 23    0.994655     0.587787
# 24    0.994655     0.587386
# 25    0.994655     0.588990
# 26    0.995724     0.589391
# 27    0.996259     0.590326
# 28    0.996793     0.590326
# 29    0.996793     0.589925
# 30    0.996793     0.590460
# 31    0.997328     0.590192
# 32    0.997328     0.590192
# 33    0.997328     0.590192
# 34    0.997328     0.590460
# 35    0.997328     0.590861
# 36    0.997862     0.591261
# 37    0.998397     0.591261
# 38    0.998397     0.591529
# 39    0.998397     0.591395
# 40    0.998397     0.591662
# 41    0.998931     0.591929
# 42    0.998931     0.591662
# 43    0.998931     0.591796
# 44    0.998931     0.591929
# 45    0.998931     0.592731
# 46    0.999466     0.592731
# 47    0.999466     0.592865
# 48    0.999466     0.592731
# 49    0.999466     0.592998
# 50    0.999466     0.592731
# 51    0.999466     0.592865
# 52    0.999466     0.592731
# 53    0.999466     0.592731
# 54    0.999466     0.592731
# 55    0.999466     0.592731
# 56    0.999466     0.592731
# 57    0.999466     0.592998
# 58    0.999466     0.593533
# 59    1.000000     0.593533

# %%
model_out.perc_happy.plot()
plt.xlabel("Step")
plt.ylabel("% Happy Agents")
plt.ylim(min(model_out.perc_happy),1)
# Out:
# (0.7258150721539284, 1.0)

# %%
model_out.segregation.plot()
plt.xlabel("Step")
plt.ylabel("<S>")
# Out:
# Text(0, 0.5, '<S>')

# %% [markdown]
# # Effect of Homophily on segregation
#
# Now, we can do a parameter sweep to see how segregation changes with homophily.
#
# First, we create a function which takes a model instance and returns what fraction of agents are segregated -- that is, have no neighbors of the opposite type.

# %%
from mesa import batch_run

# %% [markdown]
# Now, we set up the batch run, with a dictionary of fixed and changing parameters. Let's hold everything fixed except for Homophily.

# %%
fixed_params = {
    'width': 50,
    'height': 50,
    'density': 0.75,
    'minority_pc': 0.4,
    'homophily': 3,
    'follow_policy': 1.0
}

#policies = ["random", "distance", "relevance", "distance_relevance", "rich_neighborhood", "poor_neighborhood", "minimum_improvement", "maximum_improvement", "recently_emptied", "historically_emptied" ]

#policies = ["random", "distance_relevance", "rich_neighborhood", 
#            "minimum_improvement", "maximum_improvement", "recently_emptied", 
#            "similar_neighborhood", "different_neighborhood" ]
policies = ["random", "distance", "relevance", "distance_relevance", "rich_neighborhood", "poor_neighborhood",
            "minimum_improvement", "maximum_improvement", "recently_emptied", "historically_emptied", "empty_surrounded", 
            "similar_neighborhood", "different_neighborhood", "similar_history_cell", "similar_history_neighborhood"]

percentages = [i / 10 for i in range(4,10)]

variable_parms = {"policy": policies, "altruism": percentages}

merged_params = {**fixed_params, **variable_parms}
merged_params
# Out:
# {'width': 50,
#  'height': 50,
#  'density': 0.75,
#  'minority_pc': 0.4,
#  'homophily': 3,
#  'follow_policy': 1.0,
#  'policy': ['random',
#   'distance',
#   'relevance',
#   'distance_relevance',
#   'rich_neighborhood',
#   'poor_neighborhood',
#   'minimum_improvement',
#   'maximum_improvement',
#   'recently_emptied',
#   'historically_emptied',
#   'empty_surrounded',
#   'similar_neighborhood',
#   'different_neighborhood',
#   'similar_history_cell',
#   'similar_history_neighborhood'],
#  'altruism': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]}

# %%
pd.options.mode.chained_assignment = None

results = batch_run(
    Schelling,
    parameters = merged_params,
    iterations=50,
    max_steps=100,
    number_processes = None
);

results_df = pd.DataFrame(results)

# %%
#results_df.to_csv("results_nico.csv", index=False)
results_df = pd.read_csv("results_nico.csv")
results_df[(results_df['policy'] == 'random') & (results_df['altruism'] == 0.4)].count()
# Out:
# RunId            50
# iteration        50
# Step             50
# width            50
# height           50
# density          50
# minority_pc      50
# homophily        50
# follow_policy    50
# policy           50
# altruism         50
# perc_happy       50
# segregation      50
# dtype: int64

# %%
results_df = results_df[["RunId", "iteration", "Step", "follow_policy", "policy",  "segregation", "altruism"]]
#calculate the average Step and the average segregation, across different iteration and policy
results_df_g = results_df.groupby(['policy', 'altruism']).mean().reset_index()
results_df_g.head(50)
# Out:
#                     policy  altruism   RunId  iteration    Step
# 0   different_neighborhood       0.4  2277.0       24.5   76.68  \
# 1   different_neighborhood       0.5  2278.0       24.5   75.50
# 2   different_neighborhood       0.6  2279.0       24.5   80.94
# 3   different_neighborhood       0.7  2280.0       24.5   75.86
# 4   different_neighborhood       0.8  2281.0       24.5   65.30
# 5   different_neighborhood       0.9  2282.0       24.5   49.34
# 6                 distance       0.4  2211.0       24.5  100.00
# 7                 distance       0.5  2212.0       24.5  100.00
# 8                 distance       0.6  2213.0       24.5  100.00
# 9                 distance       0.7  2214.0       24.5  100.00
# 10                distance       0.8  2215.0       24.5  100.00
# 11                distance       0.9  2216.0       24.5  100.00
# 12      distance_relevance       0.4  2223.0       24.5   83.50
# 13      distance_relevance       0.5  2224.0       24.5   82.36
# 14      distance_relevance       0.6  2225.0       24.5   81.32
# 15      distance_relevance       0.7  2226.0       24.5   78.14
# 16      distance_relevance       0.8  2227.0       24.5   68.76
# 17      distance_relevance       0.9  2228.0       24.5   56.28
# 18        empty_surrounded       0.4  2265.0       24.5   98.58
# 19        empty_surrounded       0.5  2266.0       24.5  100.00
# 20        empty_surrounded       0.6  2267.0       24.5   99.82
# 21        empty_surrounded       0.7  2268.0       24.5   98.42
# 22        empty_surrounded       0.8  2269.0       24.5   96.44
# 23        empty_surrounded       0.9  2270.0       24.5   97.92
# 24    historically_emptied       0.4  2259.0       24.5   29.06
# 25    historically_emptied       0.5  2260.0       24.5   28.18
# 26    historically_emptied       0.6  2261.0       24.5   27.80
# 27    historically_emptied       0.7  2262.0       24.5   26.50
# 28    historically_emptied       0.8  2263.0       24.5   27.70
# 29    historically_emptied       0.9  2264.0       24.5   29.96
# 30     maximum_improvement       0.4  2247.0       24.5   25.50
# 31     maximum_improvement       0.5  2248.0       24.5   27.22
# 32     maximum_improvement       0.6  2249.0       24.5   27.60
# 33     maximum_improvement       0.7  2250.0       24.5   30.72
# 34     maximum_improvement       0.8  2251.0       24.5   27.50
# 35     maximum_improvement       0.9  2252.0       24.5   30.46
# 36     minimum_improvement       0.4  2241.0       24.5   24.88
# 37     minimum_improvement       0.5  2242.0       24.5   29.32
# 38     minimum_improvement       0.6  2243.0       24.5   28.06
# 39     minimum_improvement       0.7  2244.0       24.5   31.78
# 40     minimum_improvement       0.8  2245.0       24.5   30.02
# 41     minimum_improvement       0.9  2246.0       24.5   28.68
# 42       poor_neighborhood       0.4  2235.0       24.5  100.00
# 43       poor_neighborhood       0.5  2236.0       24.5  100.00
# 44       poor_neighborhood       0.6  2237.0       24.5  100.00
# 45       poor_neighborhood       0.7  2238.0       24.5  100.00
# 46       poor_neighborhood       0.8  2239.0       24.5  100.00
# 47       poor_neighborhood       0.9  2240.0       24.5  100.00
# 48                  random       0.4  2205.0       24.5   27.90
# 49                  random       0.5  2206.0       24.5   27.74
#
#     follow_policy  segregation
# 0             1.0     0.667868
# 1             1.0     0.662704
# 2             1.0     0.657105
# 3             1.0     0.654755
# 4             1.0     0.651074
# 5             1.0     0.647469
# 6             1.0     0.473014
# 7             1.0     0.498022
# 8             1.0     0.527619
# 9             1.0     0.554354
# 10            1.0     0.582687
# 11            1.0     0.610997
# 12            1.0     0.618599
# 13            1.0     0.624197
# 14            1.0     0.626060
# 15            1.0     0.630032
# 16            1.0     0.633878
# 17            1.0     0.638557
# 18            1.0     0.608992
# 19            1.0     0.613371
# 20            1.0     0.616303
# 21            1.0     0.620490
# 22            1.0     0.628022
# 23            1.0     0.634012
# 24            1.0     0.656536
# 25            1.0     0.653211
# 26            1.0     0.651742
# 27            1.0     0.648481
# 28            1.0     0.645615
# 29            1.0     0.644958
# 30            1.0     0.715179
# 31            1.0     0.707347
# 32            1.0     0.694950
# 33            1.0     0.681405
# 34            1.0     0.672786
# 35            1.0     0.658315
# 36            1.0     0.598354
# 37            1.0     0.606734
# 38            1.0     0.617691
# 39            1.0     0.625435
# 40            1.0     0.631890
# 41            1.0     0.638059
# 42            1.0     0.472745
# 43            1.0     0.498486
# 44            1.0     0.524970
# 45            1.0     0.554922
# 46            1.0     0.582139
# 47            1.0     0.615167
# 48            1.0     0.651142
# 49            1.0     0.649864

# %%
#per each policy, extract the timeseries of Step and segregation
results_df_g_step = results_df_g.pivot(index='altruism', columns='policy', values='Step')
results_df_g_segregation = results_df_g.pivot(index='altruism', columns='policy', values='segregation')

# %%
#plot the timeseries of Step
results_df_g_step.plot()
plt.xlabel("Altruism(%)")
plt.ylabel("nr. steps")
# Out:
# Text(0, 0.5, 'nr. steps')

# %%
#plot the timeseries of S
results_df_g_segregation.plot()
plt.xlabel("Altruism (%)")
plt.ylabel("<S>")
# Out:
# Text(0, 0.5, '<S>')

# %%
results_df
# Out:
#       RunId  iteration  Step  follow_policy             policy  segregation
# 0        55          0    14            0.0   recently_emptied     0.657536
# 1        10          0    17            1.0             random     0.661243
# 2        22          0    18            0.0  rich_neighborhood     0.645744
# 3         9          0    23            0.9             random     0.646534
# 4         6          0    19            0.6             random     0.656921
# ...     ...        ...   ...            ...                ...          ...
# 4395   4287         48   100            0.8   recently_emptied     0.643837
# 4396   4289         48   100            1.0   recently_emptied     0.607239
# 4397   4200         47   100            0.9   recently_emptied     0.606190
# 4398   4376         49   100            0.9   recently_emptied     0.619856
# 4399   4377         49   100            1.0   recently_emptied     0.608012
#
# [4400 rows x 6 columns]

# %%
#in results_df_g_std, calculate both the standard deviation and the mean of Step and segregation, across different iteration and policy

results_df_g_std = results_df.groupby(['policy', 'altruism']).agg({'Step': ['std', 'mean'], 'segregation': ['std', 'mean']}).reset_index()
results_df_g_std.columns = results_df_g_std.columns.droplevel(0)
results_df_g_std.columns = ['policy', 'altruism', 'Step_std', 'Step_mean', 'segregation_std', 'segregation_mean']
results_df_g_std.head(20)
# Out:
#                     policy  altruism   Step_std  Step_mean  segregation_std
# 0   different_neighborhood       0.4  34.896605      76.68         0.007859  \
# 1   different_neighborhood       0.5  33.430555      75.50         0.008169
# 2   different_neighborhood       0.6  31.701033      80.94         0.009417
# 3   different_neighborhood       0.7  33.175483      75.86         0.007857
# 4   different_neighborhood       0.8  33.579786      65.30         0.009081
# 5   different_neighborhood       0.9  30.558482      49.34         0.007908
# 6                 distance       0.4   0.000000     100.00         0.008242
# 7                 distance       0.5   0.000000     100.00         0.007636
# 8                 distance       0.6   0.000000     100.00         0.007905
# 9                 distance       0.7   0.000000     100.00         0.007526
# 10                distance       0.8   0.000000     100.00         0.010027
# 11                distance       0.9   0.000000     100.00         0.008609
# 12      distance_relevance       0.4  20.275903      83.50         0.006326
# 13      distance_relevance       0.5  20.676083      82.36         0.008343
# 14      distance_relevance       0.6  19.161441      81.32         0.009076
# 15      distance_relevance       0.7  23.319441      78.14         0.008624
# 16      distance_relevance       0.8  26.401577      68.76         0.007462
# 17      distance_relevance       0.9  25.772981      56.28         0.008691
# 18        empty_surrounded       0.4  10.040916      98.58         0.008329
# 19        empty_surrounded       0.5   0.000000     100.00         0.008166
#
#     segregation_mean
# 0           0.667868
# 1           0.662704
# 2           0.657105
# 3           0.654755
# 4           0.651074
# 5           0.647469
# 6           0.473014
# 7           0.498022
# 8           0.527619
# 9           0.554354
# 10          0.582687
# 11          0.610997
# 12          0.618599
# 13          0.624197
# 14          0.626060
# 15          0.630032
# 16          0.633878
# 17          0.638557
# 18          0.608992
# 19          0.613371

# %%
results_df_g_mean_step = results_df_g_std.pivot(index='altruism', columns='policy', values='Step_mean')
results_df_g_std_step = results_df_g_std.pivot(index='altruism', columns='policy', values='Step_std')

results_df_g_std_segregation = results_df_g_std.pivot(index='altruism', columns='policy', values='segregation_std')
results_df_g_mean_segregation = results_df_g_std.pivot(index='altruism', columns='policy', values='segregation_mean')

# %%
#join all the columns of the dataframe, so that we have the standard deviation and the mean of Step and segregation, per each policy, with different colors
for column in results_df_g_std_step.columns:
    if column == "random": #the baseline must be thicker and a normal line without error bars
        #plt.plot(results_df_g_mean_step.index, results_df_g_mean_step[column], label=column, linewidth=5, color = "black")
        plt.errorbar(results_df_g_mean_step.index, results_df_g_mean_step[column], yerr=results_df_g_std_step[column], label=column, linewidth=5, color = "black")
    else:
        plt.errorbar(results_df_g_mean_step.index, results_df_g_mean_step[column], yerr=results_df_g_std_step[column], label=column)

plt.xlabel("Altruism(%)", fontsize=18)
plt.ylabel("nr. steps", fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(loc='upper left')
plt.show()

# %%
for column in results_df_g_std_segregation.columns:
    if column == "random": #the baseline must be thicker and a normal line without error bars
        plt.errorbar(results_df_g_mean_segregation.index, results_df_g_mean_segregation[column], yerr=results_df_g_std_segregation[column], label=column, linewidth=5, color = "black")
    else:
        plt.errorbar(results_df_g_mean_segregation.index, results_df_g_mean_segregation[column], yerr=results_df_g_std_segregation[column], label=column)

plt.xlabel("Altruism (%)", fontsize=18)
plt.ylabel("segregation", fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(loc='upper left')
plt.show()
